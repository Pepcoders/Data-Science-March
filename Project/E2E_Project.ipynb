# %% [markdown]
# <a href="https://colab.research.google.com/github/Pepcoders/Data-Science-March/blob/main/Project/E2E_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/purna135/ML-Datasets/main/California-Housing-Prices.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16058    -122.49     37.76                  52       1792.0           305.0
# 6171     -117.92     34.08                  35       2108.0           408.0
# 19518    -121.01     37.64                  33        693.0           207.0
# 14192    -117.07     32.69                  20       2192.0           406.0
# 855      -122.02     37.58                  15       3052.0           760.0
#
#        population  households  median_income  median_house_value  \
# 16058       782.0       287.0         4.0391            332700.0
# 6171       1257.0       414.0         4.1312            185200.0
# 19518       598.0       192.0         1.0217             81300.0
# 14192      1766.0       393.0         4.0921            135000.0
# 855        2097.0       728.0         3.3617            178100.0
#
#       ocean_proximity
# 16058        NEAR BAY
# 6171        <1H OCEAN
# 19518          INLAND
# 14192      NEAR OCEAN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.describe()nk
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df["housing_median_age"].min()
# Out:
# 1.0

# %%
df["housing_median_age"].max()
# Out:
# 52.0

# %%
df["housing_median_age"].dtype
# Out:
# dtype('float64')

# %%
df["housing_median_age"] = df["housing_median_age"].astype("int8")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int8
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(8), int8(1), object(1)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41        880.0           129.0
# 1    -122.22     37.86                  21       7099.0          1106.0
# 2    -122.24     37.85                  52       1467.0           190.0
# 3    -122.25     37.85                  52       1274.0           235.0
# 4    -122.25     37.85                  52       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import matplotlib.pyplot as plt

plt.hist(df["median_house_value"])
plt.show()

# %%
import seaborn as sns
sns.displot(df["median_house_value"], kde=True)
plt.show()

# %%
df["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
sns.countplot(data = df, x = "ocean_proximity")

# %%
sns.boxplot(df["ocean_proximity"], df["median_house_value"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import plotly.express as px

px.box(df, x= "ocean_proximity", y = "median_house_value")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41        880.0           129.0
# 1    -122.22     37.86                  21       7099.0          1106.0
# 2    -122.24     37.85                  52       1467.0           190.0
# 3    -122.25     37.85                  52       1274.0           235.0
# 4    -122.25     37.85                  52       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.figure(figsize = (16,12))
plt.scatter(df['longitude'], df["latitude"], alpha=0.2)

# %%
plt.figure(figsize = (16,12))
plt.scatter(df['longitude'], df["latitude"], alpha = 0.5, c=df["median_house_value"], cmap='nipy_spectral', s = df["population"]/40)
plt.colorbar()

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
df.corr()["median_house_value"].sort_values(ascending = False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
plt.figure(figsize = (12, 10))
sns.heatmap(df.corr(), cmap = "jet", annot = True, lw = 3)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41        880.0           129.0
# 1    -122.22     37.86                  21       7099.0          1106.0
# 2    -122.24     37.85                  52       1467.0           190.0
# 3    -122.25     37.85                  52       1274.0           235.0
# 4    -122.25     37.85                  52       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df["rooms_per_house"] = df["total_rooms"]/df["households"]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41        880.0           129.0
# 1    -122.22     37.86                  21       7099.0          1106.0
# 2    -122.24     37.85                  52       1467.0           190.0
# 3    -122.25     37.85                  52       1274.0           235.0
# 4    -122.25     37.85                  52       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_house
# 0         6.984127
# 1         6.238137
# ...

# %%
df["rooms_per_population"] = df["total_rooms"]/df["population"]

# %%
df["beedroom_per_room"] = df["total_bedrooms"]/df["total_rooms"]

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41        880.0           129.0
# 1        -122.22     37.86                  21       7099.0          1106.0
# 2        -122.24     37.85                  52       1467.0           190.0
# 3        -122.25     37.85                  52       1274.0           235.0
# 4        -122.25     37.85                  52       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25       1665.0           374.0
# 20636    -121.21     39.49                  18        697.0           150.0
# 20637    -121.22     39.43                  17       2254.0           485.0
# 20638    -121.32     39.43                  18       1860.0           409.0
# 20639    -121.24     39.37                  16       2785.0           616.0
#
# ...

# %%
df.corr()["median_house_value"].sort_values(ascending = False)
# Out:
# median_house_value      1.000000
# median_income           0.688075
# rooms_per_population    0.209482
# rooms_per_house         0.151948
# total_rooms             0.134153
# housing_median_age      0.105623
# households              0.065843
# total_bedrooms          0.049686
# population             -0.024650
# longitude              -0.045967
# latitude               -0.144160
# beedroom_per_room      -0.255880
# Name: median_house_value, dtype: float64

# %%
df.isna().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms               0
# total_bedrooms          207
# population                0
# households                0
# median_income             0
# median_house_value        0
# ocean_proximity           0
# rooms_per_house           0
# rooms_per_population      0
# beedroom_per_room       207
# dtype: int64

# %%
df["total_bedrooms"].median()
# Out:
# 435.0

# %%
df["total_rooms"].min()
# Out:
# 2.0

# %%
df["total_bedrooms"] = df["total_bedrooms"].fillna(df["total_bedrooms"].median())

# %%
df.isna().sum()
# Out:
# longitude                 0
# latitude                  0
# housing_median_age        0
# total_rooms               0
# total_bedrooms            0
# population                0
# households                0
# median_income             0
# median_house_value        0
# ocean_proximity           0
# rooms_per_house           0
# rooms_per_population      0
# beedroom_per_room       207
# dtype: int64

# %%
df["beedroom_per_room"] = df["total_bedrooms"]/df["total_rooms"]

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms          0
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# rooms_per_house         0
# rooms_per_population    0
# beedroom_per_room       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy = "median")

si.fit(df[["total_bedrooms"]])
si.transform(df[["total_bedrooms"]])
# Out:
# array([[ 129.],
#        [1106.],
#        [ 190.],
#        ...,
#        [ 485.],
#        [ 409.],
#        [ 616.]])

# %%
si.fit_transform(df[["total_bedrooms"]])
# Out:
# array([[ 129.],
#        [1106.],
#        [ 190.],
#        ...,
#        [ 485.],
#        [ 409.],
#        [ 616.]])
